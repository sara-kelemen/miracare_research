# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
logprob = pd.read_csv('/content/cycles_logprob_interp - cycles_logprob_interp.csv',na_values=[np.inf,-np.inf])

# %%
dictionary_ages = pd.read_csv('/content/user_dictionary_per_user_cycle.csv')

# %%
logprob.head()
# Out:
#             hub_id  cycle_index  logprob
# 0  U2CCD5D16315123           31      NaN
# 1  U303F6B17404145            7      NaN
# 2  U2E649816722750           19      NaN
# 3  U2F50A717152551           10      NaN
# 4  U2F191017106760           19      NaN

# %%
# graph e3g (estrogen), pdg (prodgesterone), and Lh: days x axis, -inf/not -inf
# age vs fit, PCOS/baseline vs fit
# HMM trained on baseline, fit may be worse for PCOS cycle
# Alexis' run did not show that it was worse but may be different
# she ran the fit of best path, this is all possible paths
# MISSING DATA:
# data is already interpolated, but we can find the data before it was interpolated
# amount of missing data may affect this
# percent missing data vs. fit
# in non interpolated file, what proportion is missing
# pattern of missingness?
# make a file where each row is continuous time for a single person (user cycles concatenated), include NaNs

# %%
sns.histplot(data=logprob,x='logprob')
plt.xlabel('Log Probability')
plt.ylabel('Frequency')
plt.title('Distribution of Log Probabilities')
# Out:
# Text(0.5, 1.0, 'Distribution of Log Probabilities')
